# %%
print(5//2)
# Out:
# 2

# %%
print(5%2)
# Out:
# 1

# %%
print(5**2)
# Out:
# 25

# %%
print(5+1)
# Out:
# 6

# %%
print(5-1)
# Out:
# 4

# %%
# realtional operators
print(5>2)
print(5<2)
print(5>=2)
print(5<=2)
print(5==2)
print(5!=2)
# Out:
# True
# False
# True
# False
# False
# True

# %%
a=int(input("enter the value of a:"))
b=int(input("enter the value of b:"))
c=int(input("enter the value of c:"))
result = a+b+c
print("The sum of three numbers is : ", result)
# Out:
# The sum of three numbers is :  6

# %%
print('D' not in "Django")
print(1 in [2,3,4,5,6])
# Out:
# False
# False

# %%
number=int(input("Enter a number:"))
print("The number is :", number)
a = number % 10
number = number // 10
b = number % 10
number = number // 10
c= number % 10
sum =  a+ b + c
print("The sum of digits is :", sum)
# Out:
# The number is : 123
# The sum of digits is : 6

# %%
email = input("Enter  the email : ")
password = input("Enter the password: ")

if email == "nitish@gmail.com" and password =="nitish":
        print("Login Successfull")
else: 
        print("Login Failed ")
# Out:
# Login Failed
