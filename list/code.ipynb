# %%
# list 
l1=[1,2,3.343,'hello',True]
print(l1)
# Out:
# [1, 2, 3.343, 'hello', True]

# %%
print(id(l1))
print(id(l1[0]))
print(id(l1[1]))
print(id(l1[2]))
print(id(l1[3]))
print(id(l1[4]))

print(id(1))
print(id(2))
print(id(3.343))
print(id('hello'))
print(id(True))
# Out:
# 1860792711616
# 1860715675888
# 1860715675920
# 1860792467952
# 1860788765104
# 140726242909032
# 1860715675888
# 1860715675920
# 1860792483504
# 1860788765104
# 140726242909032
