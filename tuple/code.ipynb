# %%
t1=()
print(t1)
# Out:
# ()

# %%
t2=('hello')
print(t2)
print(type(t2))
# Out:
# hello
# <class 'str'>

# %%
t2=('hello',)
print(t2)
print(type(t2))
# Out:
# ('hello',)
# <class 'tuple'>

# %%
t3=('hello', 'world', 2024, 3.14, True) 
print(t3)
print(type(t3))

t4=(1,2,3,"deepu",("Helo","world", 33))
print(t4)
print(type(t4))

# typecasting list to tuple
t=tuple("hello")
print(t)
# Out:
# ('hello', 'world', 2024, 3.14, True)
# <class 'tuple'>
# (1, 2, 3, 'deepu', ('Helo', 'world', 33))
# <class 'tuple'>
# ('h', 'e', 'l', 'l', 'o')
