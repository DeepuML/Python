# %%
t1=()
print(t1)
# Out:
# ()

# %%
t2=('hello')
print(t2)
print(type(t2))
# Out:
# hello
# <class 'str'>

# %%
t2=('hello',)
print(t2)
print(type(t2))
# Out:
# ('hello',)
# <class 'tuple'>

# %%
t3=('hello', 'world', 2024, 3.14, True) 
print(t3)
print(type(t3))

t4=(1,2,3,"deepu",("Helo","world", 33))
print(t4)
print(type(t4))

# typecasting list to tuple
t=tuple("hello")
print(t)
# Out:
# ('hello', 'world', 2024, 3.14, True)
# <class 'tuple'>
# (1, 2, 3, 'deepu', ('Helo', 'world', 33))
# <class 'tuple'>
# ('h', 'e', 'l', 'l', 'o')

# %%
t3=(1,2,3,4,5,6,'hello', 'world', 2024, 3.14, True)
print(t3[0])
print(t3[6][0])
print(t3[-1])
# Out:
# 1
# h
# True

# %%
t1=(1,2,3,4,5)
t2=(1,2,3,4,5)

t1+t2
t1*3

for i in t1: 
    print(i*3)
# Out:
# 3
# 6
# 9
# 12
# 15

# %%
t1=(1,2,3,4,5)

print(len(t1))
print(max(t1))
print(sum(t1))
print(min(t1))
print(sorted(t1))
# Out:
# 5
# 5
# 15
# 1
# [1, 2, 3, 4, 5]

# %%
# count 
print(t1.count(3))
# Out:
# 1

# %%
# Set 

s={}
print(s)
print(type(s))
# Out:
# {}
# <class 'dict'>

# %%
s=set()
print(s)
print(type(s))
# Out:
# set()
# <class 'set'>

# %%
s1={1,2,3,4,5,5,5,5,5} # duplicates not allowed
print(s1)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1={1,2,3,"hello",True}
s1
# Out:
# {1, 2, 3, 'hello'}

# %%
# set cant have mutable items  
s2={1,2,4,[3,4,5],'deep'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # set cant have mutable items
# ----> 2 s2={1,2,4,[3,4,5],'deep'}
#
# TypeError: unhashable type: 'list'

# %%
s1={1,2,3}
s2={3,2,1}

print(s1==s2)
# Out:
# True

# %%
s={1,2,3,4,5}
s.add(6)
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s={1,2,3,4,5}
s.update([6,7])
s
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
# dicitonary 
d={}
print(d)
type(d)
# Out:
# {}
# dict

# %%
d1={'name':'deepu','address':'kerala'}
d1
# Out:
# {'name': 'deepu', 'address': 'kerala'}

# %%
d2={'name':'deepu', 'age':30, 'address':'banglore'}
print(d2)
# Out:
# {'name': 'deepu', 'age': 30, 'address': 'banglore'}

# %%
d={
    'name':'deepu',
    'college':'xyz',
    'address':'kerala',
    'subjects':{
        'sub1':'maths',
        'sub2':'science',
        'sub3':'english'
    }
}

# %%
a=dict([(1,2),(3,4),(5,6)])
a
# Out:
# {1: 2, 3: 4, 5: 6}

# %%
d={
    'name':'deepu',
    'college':'xyz',
    'address':'kerala',
    'subjects':{
        'sub1':'maths',
        'sub2':'science',
        'sub3':'english'
    }
}

d['name']
# Out:
# 'deepu'

# %%
d.get('college')
# Out:
# 'xyz'

# %%
d.pop('address')
# Out:
# 'kerala'

# %%
d
# Out:
# {'name': 'deepu',
#  'college': 'xyz',
#  'subjects': {'sub1': 'maths', 'sub2': 'science', 'sub3': 'english'}}

# %%
d['address']='banglore'

# %%
d
# Out:
# {'name': 'deepu',
#  'college': 'xyz',
#  'subjects': {'sub1': 'maths', 'sub2': 'science', 'sub3': 'english'},
#  'address': 'banglore'}
